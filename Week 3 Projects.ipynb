# %% [markdown]
# # Project 1
# #### Matric Number: 21120612459
# #### E-mail: timothy.eyo@pau.edu.ng
# #### Name: Timothy Eyo
#
# #### PSEUDOCODE
#
# #### START
# #### Input = n
# #### COMPUTE  n - 17
# #### If n > 17
# #### PRINT as (ans * 2)
# #### If n < 17
# #### PRINT abs (ans)
# #### PRINT A (ans)
# #### STOP
# ![image.png](attachment:image.png)

# %% [markdown]
# # Project 2
# #### PSEUDOCODE
#
# #### START
# #### INPUT = a, b, c
# #### COMPUTE a + b + c
# #### PRINT ans
# #### If a = b = c
# #### PRINT ans * 3
# #### STOP
# ![image.png](attachment:image.png)

# %% [markdown]
# # Project 3
# #### PSEUDOCODE
#
# #### START
# #### INPUT = a, b
# #### COMPUTE
# #### A = (a = b)
# #### B = (a + b = 5)
# #### C = (a - b = 5)
# #### If A
# #### PRINT ('TRUE')
# #### ELIF
# #### If B
# #### PRINT ('TRUE')
# #### ELIF
# #### If C
# #### PRINT ('TRUE')
# #### ELSE
# #### PRINT ('FALSE')
# #### STOP
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Project 4
# #### PSEUDOCODE
#
# #### START
# #### INPUT
