# %% [markdown]
# # Project 1
# #### Matric Number: 21120612459
# #### E-mail: timothy.eyo@pau.edu.ng
# #### Name: Timothy Eyo
#
# #### PSEUDOCODE
#
# #### START
# #### Input = n
# #### COMPUTE  n - 17
# #### If n > 17
# #### PRINT as (ans * 2)
# #### If n < 17
# #### PRINT abs (ans)
# #### PRINT A (ans)
# #### STOP
# ![image.png](attachment:image.png)

# %%
b = int(input("input number"))
ans = b-17
if b < 17:
    print (ans*2)
else:
    t = b-17
    print (t)

# %% [markdown]
# # Project 2
# #### PSEUDOCODE
#
# #### START
# #### INPUT = a, b, c
# #### COMPUTE a + b + c
# #### PRINT ans
# #### If a = b = c
# #### PRINT ans * 3
# #### STOP
# ![image.png](attachment:image.png)

# %%
a = int(input("input number"))
b = int(input("input numbeer"))
c = int(input("input number"))

ans = a + b + c
if a==b and b==c and c==a:
    print (ans*3)
else:
        print(ans)

# %% [markdown]
# # Project 3
# #### PSEUDOCODE
#
# #### START
# #### INPUT = a, b
# #### COMPUTE
# #### A = (a = b)
# #### B = (a + b = 5)
# #### C = (a - b = 5)
# #### If A
# #### PRINT ('TRUE')
# #### ELIF
# #### If B
# #### PRINT ('TRUE')
# #### ELIF
# #### If C
# #### PRINT ('TRUE')
# #### ELSE
# #### PRINT ('FALSE')
# #### STOP
# ![image.png](attachment:image.png)

# %%
a = int(input("input number"))
b = int(input("input number"))
if a = b
    print("TRUE")
elif a + b = 5
    print ("TRUE")
elif a - b = 5
    print ("TRUE")
else
    print ("FALSE")

# %% [markdown]
# # Project 4
# #### PSEUDOCODE
#
# #### START
# #### INPUT a, b, c
# #### INPUT x1=max(a, b, c)
# #### INPUT x2=min(a, b, c)
# #### INPUT x3=(a + b + c)-x1-x2
# #### STOP
#
# ![image.png](attachment:image.png)

# %%
a = int(input("input number"))
b = int(input("input number"))
c = int(input("input number"))

x1 = max(a, b, c)
x2 = min(a, b, c)
x3 = (a + b + c)-(x1-x2)

print(x1, x2, x3)

# %% [markdown]
# #### PROJECT 5
# #### PSEUDOCODE
# #### START
# #### INPUT a
# #### IF a < 6
# #### PRINT a**a
# #### ELSE
# #### PRINT a
# #### STOP
#
# ![image.png](attachment:image.png)

# %%
a = int(input("input number"))
if a < 6:
    print  (a**a)
else:
    a>6
    print (a)
